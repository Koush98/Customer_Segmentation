# %% [markdown]
# # Solving provided questions on Toyota 2nd hand car data set

# %%
# 1) load the data set with replacing the special characters by NAN

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\Admin\\Desktop\\koushik\\data_sets\\Toyota(1).csv",na_values=["?","??","???","????"],index_col=0)
df
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
# 2) What is the shape of the Data set
df.shape
# Out:
# (1436, 10)

# %%
# 3) What are the columns in the data set?
df.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %%
# 4) What is the Dimension of data set.
df.dtypes
# Out:
# Price          int64
# Age          float64
# KM           float64
# FuelType      object
# HP           float64
# MetColor     float64
# Automatic      int64
# CC             int64
# Doors         object
# Weight         int64
# dtype: object

# %%
# 5) Count the number of int , float and object columns in the data set.
df.dtypes.value_counts()
# Out:
# int64      4
# float64    4
# object     2
# dtype: int64

# %%
# 6) Print the unique values in "KM" column.
df["KM"].unique()
# Out:
# array([46986., 72937., 41711., ..., 30964., 20544., 17016.])

# %%
# 7) Replace "three","four" as 3,4,5 in the "Doors" column.
df["Doors"]=df["Doors"].replace({"three":3, "four":4, "five":5})
df["Doors"]
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1431    3
# 1432    3
# 1433    3
# 1434    3
# 1435    5
# Name: Doors, Length: 1436, dtype: object

# %%
# 8) How many missing values are there
df.isnull().sum()
# Out:
# Price          0
# Age          100
# KM            15
# FuelType     100
# HP             6
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
# 9) Fill the missing values by their mean, median, mode whatever is applicable.
df["Age"].fillna(df["Age"].mean(), inplace=True)

# %%
df["KM"].fillna(df["KM"].mean(),inplace=True)

# %%
df["FuelType"].fillna(df["FuelType"].mode()[0],inplace=True)

# %%
df["HP"].fillna(df["HP"].mean(),inplace=True)

# %%
df["MetColor"].fillna(df["MetColor"].mode()[0],inplace=True)

# %%
# 10) Create a scatter plot betwwen "Age" and "Price".
plt.scatter(df["Age"],df["Price"],marker="*")
plt.title("Scatter Plot of Age & Price")
plt.xlabel("Age")
plt.ylabel("Price")
plt.show()

# %%
# 11) Plot a histogram of "KM" with appropriate title and labels which will show thw values of "KM" in 
#  X axis with corresponding frequencies in Y axis. 
plt.hist(x=df["KM"])
plt.xlabel("Kilometer")
plt.ylabel("Frequency")
plt.show()

# %%
# 12) Construct a density plot of "Age"
sns.displot(df["Age"])
plt.show()

# %%
# 13) Create a box plot of "price"
sns.boxplot(df["Price"],color="red")
plt.xlabel("Price")
plt.ylabel("frequency")
plt.show()

# %%
# 14) Create a count plot between "Fuel Type" and "Automatic" and 
#  study about what kind of Fueltype cars are having manual Gear Box

# Create count plot
plt.figure(figsize=(10, 6))
sns.countplot(x='FuelType',hue='Automatic', data=df)
plt.title('Distribution of Manual Gearbox Cars by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# 15) What type of Fueltype is working on most of the cars. 
df["FuelType"].value_counts().max()
# Out:
# 1277
